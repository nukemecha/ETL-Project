# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql://postgres:Tiamet7@localhost:5432/etl2')

# %%
bigmac = pd.read_csv('cleaned/bigmac.csv')
booze = pd.read_csv('cleaned/booze.csv')
gender = pd.read_csv('cleaned/gender.csv')
happy = pd.read_csv('cleaned/happy.csv')

# %%
gender.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
happy.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
bigmac.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
country_df = bigmac[['name','iso_a3']]
country_df
# Out:
#               name iso_a3
# 0        Argentina    ARG
# 1        Australia    AUS
# 2          Austria    AUT
# 3          Belgium    BEL
# 4           Brazil    BRA
# ..             ...    ...
# 107        Ukraine    UKR
# 108  United States    USA
# 109        Uruguay    URY
# 110      Venezuela    VEN
# 111        Vietnam    VNM
#
# [112 rows x 2 columns]

# %%
bigmac
# Out:
#               name iso_a3 currency_code  local_price     dollar_ex        date
# 0        Argentina    ARG           ARS        33.00     13.809250  2016-01-01
# 1        Australia    AUS           AUD         5.30      1.415729  2016-01-01
# 2          Austria    AUT           EUR         3.50      0.930233  2016-01-01
# 3          Belgium    BEL           EUR         3.95      0.930233  2016-01-01
# 4           Brazil    BRA           BRL        13.50      4.024800  2016-01-01
# ..             ...    ...           ...          ...           ...         ...
# 107        Ukraine    UKR           UAH        39.00     24.800000  2016-07-01
# 108  United States    USA           USD         5.04      1.000000  2016-07-01
# 109        Uruguay    URY           UYU       123.00     30.165000  2016-07-01
# 110      Venezuela    VEN           VEF      2170.00    641.400100  2016-07-01
# 111        Vietnam    VNM           VND     60000.00  22300.000000  2016-07-01
#
# [112 rows x 6 columns]

# %%
exchange_rate_df = bigmac[['name','currency_code','dollar_ex','date']]

# %%
exchange_rate_df
# Out:
#               name currency_code     dollar_ex        date
# 0        Argentina           ARS     13.809250  2016-01-01
# 1        Australia           AUD      1.415729  2016-01-01
# 2          Austria           EUR      0.930233  2016-01-01
# 3          Belgium           EUR      0.930233  2016-01-01
# 4           Brazil           BRL      4.024800  2016-01-01
# ..             ...           ...           ...         ...
# 107        Ukraine           UAH     24.800000  2016-07-01
# 108  United States           USD      1.000000  2016-07-01
# 109        Uruguay           UYU     30.165000  2016-07-01
# 110      Venezuela           VEF    641.400100  2016-07-01
# 111        Vietnam           VND  22300.000000  2016-07-01
#
# [112 rows x 4 columns]

# %%
booze
# Out:
#          Country  Beer_PerCapita  Spirit_PerCapita  Wine_PerCapita
# 0        Denmark             224                81             278
# 1    Switzerland             185               100             280
# 2        Iceland             233                61              78
# 3         Norway             169                71             129
# 4        Finland             263               133              97
# ..           ...             ...               ...             ...
# 117     Tanzania              36                 6               1
# 118      Liberia              19               152               2
# 119        Benin              34                 4              13
# 120         Togo              36                 2              19
# 121        Syria               5                35              16
#
# [122 rows x 4 columns]

# %%
beer_df = booze[['Country','Beer_PerCapita']]

# %%
liquor_df = booze[['Country','Spirit_PerCapita']]

# %%
wine_df = booze[['Country','Wine_PerCapita']]

# %%
wine_df
# Out:
#          Country  Wine_PerCapita
# 0        Denmark             278
# 1    Switzerland             280
# 2        Iceland              78
# 3         Norway             129
# 4        Finland              97
# ..           ...             ...
# 117     Tanzania               1
# 118      Liberia               2
# 119        Benin              13
# 120         Togo              19
# 121        Syria              16
#
# [122 rows x 2 columns]

# %%
cols_to_drop = ['name','dollar_ex']
bigmac.drop(cols_to_drop, axis=1, inplace=True)

# %%
bigmac
# Out:
#     iso_a3 currency_code  local_price        date
# 0      ARG           ARS        33.00  2016-01-01
# 1      AUS           AUD         5.30  2016-01-01
# 2      AUT           EUR         3.50  2016-01-01
# 3      BEL           EUR         3.95  2016-01-01
# 4      BRA           BRL        13.50  2016-01-01
# ..     ...           ...          ...         ...
# 107    UKR           UAH        39.00  2016-07-01
# 108    USA           USD         5.04  2016-07-01
# 109    URY           UYU       123.00  2016-07-01
# 110    VEN           VEF      2170.00  2016-07-01
# 111    VNM           VND     60000.00  2016-07-01
#
# [112 rows x 4 columns]

# %%
bigmac.to_sql('bigmac', engine)

# %%
gender.to_sql('gender', engine)

# %%
happy.to_sql('happy', engine)

# %%
country_df.to_sql('country', engine)

# %%
exchange_rate_df.to_sql('exchange_rate', engine)

# %%
liquor_df.to_sql('liquor', engine)

# %%
beer_df.to_sql('beer', engine)

# %%
wine_df.to_sql('wine', engine)
